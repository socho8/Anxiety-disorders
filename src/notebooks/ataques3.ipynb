# %%
import numpy as np
import pandas as pd

# %%
ataques = pd.read_csv('Ataques_num.csv')
ataques
# Out:
#         Edad  Genero  Antecedentes familiares  Nivel de estres  Sintomas  \
# 0         38       0                        0                1         3
# 1         51       0                        0                2         4
# 2         32       1                        1                2         4
# 3         64       1                        0                1         2
# 4         31       0                        1                1         4
# ...      ...     ...                      ...              ...       ...
# 119995    31       1                        1                2         2
# 119996    27       0                        0                2         4
# 119997    21       1                        0                0         0
# 119998    28       0                        0                1         0
# 119999    22       1                        0                2         0
#
#         Severidad  Impacto en la vida  Apoyo social  Nivel de ansiedad
# 0               0                   0             2                  1
# 1               0                   0             2                  3
# 2               0                   2             1                  1
# 3               1                   1             2                  2
# 4               0                   1             0                  3
# ...           ...                 ...           ...                ...
# 119995          1                   1             1                  3
# 119996          0                   1             2                  3
# 119997          1                   2             1                  2
# 119998          0                   2             1                  2
# 119999          2                   2             0                  4
#
# [120000 rows x 9 columns]

# %%
ataques = ataques.drop('Edad',axis = 1)
ataques
# Out:
#         Genero  Antecedentes familiares  Nivel de estres  Sintomas  Severidad  \
# 0            0                        0                1         3          0
# 1            0                        0                2         4          0
# 2            1                        1                2         4          0
# 3            1                        0                1         2          1
# 4            0                        1                1         4          0
# ...        ...                      ...              ...       ...        ...
# 119995       1                        1                2         2          1
# 119996       0                        0                2         4          0
# 119997       1                        0                0         0          1
# 119998       0                        0                1         0          0
# 119999       1                        0                2         0          2
#
#         Impacto en la vida  Apoyo social  Nivel de ansiedad
# 0                        0             2                  1
# 1                        0             2                  3
# 2                        2             1                  1
# 3                        1             2                  2
# 4                        1             0                  3
# ...                    ...           ...                ...
# 119995                   1             1                  3
# 119996                   1             2                  3
# 119997                   2             1                  2
# 119998                   2             1                  2
# 119999                   2             0                  4
#
# [120000 rows x 8 columns]

# %%
ataques['Nivel de ansiedad'].value_counts()
# Out:
# Nivel de ansiedad
# 1    56215
# 3    39884
# 2    20523
# 4     3378
# Name: count, dtype: int64

# %%
X = ataques.drop('Nivel de ansiedad', axis=1)
y = ataques['Nivel de ansiedad']

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 42)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rnd_clf = RandomForestClassifier(n_estimators=100, random_state=42)

# %%
rnd_clf.fit(X_test, y_test)
# Out:
# RandomForestClassifier(random_state=42)

# %%
y_pred_RFC = rnd_clf.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score

conf_matrixRFC = confusion_matrix(y_test, y_pred_RFC)

# Imprimir la matriz de confusión
print("Matriz de Confusión:")
print(conf_matrixRFC)
# Out:
# Matriz de Confusión:
# [[11316     5     0     0]
#  [  335  3691   123     0]
#  [   52     0  7779     7]
#  [    0     0    64   628]]

# %%
accuracyConf = accuracy_score(y_test, y_pred_RFC)
print("Precisión (Accuracy): {:.2f}%".format(accuracyConf*100))
# Out:
# Precisión (Accuracy): 97.56%

# %%
import numpy as np
import pandas as pd
from tensorflow import keras
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# Definir la arquitectura de la red neuronal
model = keras.Sequential([
    keras.layers.Dense(64, activation='relu', input_shape=(X_train.shape[1],)),
    keras.layers.Dense(32, activation='relu'),
    keras.layers.Dense(1, activation='sigmoid')
])

# Compilar el modelo
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Entrenar el modelo
model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test))
# Out:
# Epoch 1/50
# 3000/3000 [==============================] - 7s 2ms/step - loss: -69682.0781 - accuracy: 0.4676 - val_loss: -249136.1719 - val_accuracy: 0.4717
# Epoch 2/50
# 3000/3000 [==============================] - 5s 2ms/step - loss: -742702.1875 - accuracy: 0.4676 - val_loss: -1393492.2500 - val_accuracy: 0.4717
# Epoch 3/50
# 3000/3000 [==============================] - 5s 2ms/step - loss: -2495708.2500 - accuracy: 0.4676 - val_loss: -3760195.5000 - val_accuracy: 0.4717
# Epoch 4/50
# 3000/3000 [==============================] - 5s 2ms/step - loss: -5653677.5000 - accuracy: 0.4676 - val_loss: -7663461.5000 - val_accuracy: 0.4717
# Epoch 5/50
# 3000/3000 [==============================] - 5s 2ms/step - loss: -10506619.0000 - accuracy: 0.4676 - val_loss: -13403318.0000 - val_accuracy: 0.4717
# Epoch 6/50
# 3000/3000 [==============================] - 6s 2ms/step - loss: -17405492.0000 - accuracy: 0.4676 - val_loss: -21299858.0000 - val_accuracy: 0.4717
# Epoch 7/50
# 3000/3000 [==============================] - 6s 2ms/step - loss: -26613096.0000 - accuracy: 0.4676 - val_loss: -31617472.0000 - val_accuracy: 0.4717
# Epoch 8/50
# 3000/3000 [==============================] - 5s 2ms/step - loss: -38459000.0000 - accuracy: 0.4676 - val_loss: -44736492.0000 - val_accuracy: 0.4717
# Epoch 9/50
# 3000/3000 [==============================] - 5s 2ms/step - loss: -53274748.0000 - accuracy: 0.4676 - val_loss: -60878516.0000 - val_accuracy: 0.4717
# Epoch 10/50
# 3000/3000 [==============================] - 5s 2ms/step - loss: -71334680.0000 - accuracy: 0.4676 - val_loss: -80352632.0000 - val_accuracy: 0.4717
# Epoch 11/50
# 3000/3000 [==============================] - 6s 2ms/step - loss: -92879760.0000 - accuracy: 0.4676 - val_loss: -103460056.0000 - val_accuracy: 0.4717
# Epoch 12/50
# 3000/3000 [==============================] - 5s 2ms/step - loss: -118348112.0000 - accuracy: 0.4676 - val_loss: -130575016.0000 - val_accuracy: 0.4717
# Epoch 13/50
# 3000/3000 [==============================] - 6s 2ms/step - loss: -147949744.0000 - accuracy: 0.4676 - val_loss: -161964336.0000 - val_accuracy: 0.4717
# Epoch 14/50
# 3000/3000 [==============================] - 5s 2ms/step - loss: -182231728.0000 - accuracy: 0.4676 - val_loss: -198154144.0000 - val_accuracy: 0.4717
# Epoch 15/50
# 3000/3000 [==============================] - 5s 2ms/step - loss: -221386752.0000 - accuracy: 0.4676 - val_loss: -239248064.0000 - val_accuracy: 0.4717
# Epoch 16/50
# 3000/3000 [==============================] - 5s 2ms/step - loss: -265611568.0000 - accuracy: 0.4676 - val_loss: -285431904.0000 - val_accuracy: 0.4717
# Epoch 17/50
# 3000/3000 [==============================] - 6s 2ms/step - loss: -315349632.0000 - accuracy: 0.4676 - val_loss: -337397344.0000 - val_accuracy: 0.4717
# Epoch 18/50
# 3000/3000 [==============================] - 6s 2ms/step - loss: -370953600.0000 - accuracy: 0.4676 - val_loss: -395091072.0000 - val_accuracy: 0.4717
# Epoch 19/50
# 3000/3000 [==============================] - 6s 2ms/step - loss: -432535776.0000 - accuracy: 0.4676 - val_loss: -458857824.0000 - val_accuracy: 0.4717
# Epoch 20/50
# 3000/3000 [==============================] - 6s 2ms/step - loss: -500546848.0000 - accuracy: 0.4676 - val_loss: -529207616.0000 - val_accuracy: 0.4717
# Epoch 21/50
# 3000/3000 [==============================] - 6s 2ms/step - loss: -575220288.0000 - accuracy: 0.4676 - val_loss: -606249664.0000 - val_accuracy: 0.4717
# Epoch 22/50
# 3000/3000 [==============================] - 6s 2ms/step - loss: -657219328.0000 - accuracy: 0.4676 - val_loss: -690762112.0000 - val_accuracy: 0.4717
# Epoch 23/50
# 3000/3000 [==============================] - 6s 2ms/step - loss: -746538112.0000 - accuracy: 0.4676 - val_loss: -782454720.0000 - val_accuracy: 0.4717
# Epoch 24/50
# 3000/3000 [==============================] - 5s 2ms/step - loss: -843280832.0000 - accuracy: 0.4676 - val_loss: -881506048.0000 - val_accuracy: 0.4717
# Epoch 25/50
# 3000/3000 [==============================] - 7s 2ms/step - loss: -947681600.0000 - accuracy: 0.4676 - val_loss: -988605120.0000 - val_accuracy: 0.4717
# Epoch 26/50
# 3000/3000 [==============================] - 6s 2ms/step - loss: -1061116160.0000 - accuracy: 0.4676 - val_loss: -1104945536.0000 - val_accuracy: 0.4717
# Epoch 27/50
# 3000/3000 [==============================] - 5s 2ms/step - loss: -1182802432.0000 - accuracy: 0.4676 - val_loss: -1228791040.0000 - val_accuracy: 0.4717
# Epoch 28/50
# 3000/3000 [==============================] - 5s 2ms/step - loss: -1313266432.0000 - accuracy: 0.4676 - val_loss: -1362069248.0000 - val_accuracy: 0.4717
# Epoch 29/50
# 3000/3000 [==============================] - 6s 2ms/step - loss: -1453053056.0000 - accuracy: 0.4676 - val_loss: -1504472320.0000 - val_accuracy: 0.4717
# Epoch 30/50
# 3000/3000 [==============================] - 6s 2ms/step - loss: -1601883648.0000 - accuracy: 0.4676 - val_loss: -1655951616.0000 - val_accuracy: 0.4717
# Epoch 31/50
# 3000/3000 [==============================] - 6s 2ms/step - loss: -1760620416.0000 - accuracy: 0.4676 - val_loss: -1817432704.0000 - val_accuracy: 0.4717
# Epoch 32/50
# 3000/3000 [==============================] - 5s 2ms/step - loss: -1929767936.0000 - accuracy: 0.4676 - val_loss: -1989158272.0000 - val_accuracy: 0.4717
# Epoch 33/50
# 3000/3000 [==============================] - 5s 2ms/step - loss: -2109470976.0000 - accuracy: 0.4676 - val_loss: -2171649024.0000 - val_accuracy: 0.4717
# Epoch 34/50
# 3000/3000 [==============================] - 5s 2ms/step - loss: -2299634176.0000 - accuracy: 0.4676 - val_loss: -2364611840.0000 - val_accuracy: 0.4717
# Epoch 35/50
# 3000/3000 [==============================] - 5s 2ms/step - loss: -2500653056.0000 - accuracy: 0.4676 - val_loss: -2567994112.0000 - val_accuracy: 0.4717
# Epoch 36/50
# 3000/3000 [==============================] - 5s 2ms/step - loss: -2713181952.0000 - accuracy: 0.4676 - val_loss: -2783652864.0000 - val_accuracy: 0.4717
# Epoch 37/50
# 3000/3000 [==============================] - 5s 2ms/step - loss: -2937394432.0000 - accuracy: 0.4676 - val_loss: -3010233344.0000 - val_accuracy: 0.4717
# Epoch 38/50
# 3000/3000 [==============================] - 5s 2ms/step - loss: -3173477632.0000 - accuracy: 0.4676 - val_loss: -3248857600.0000 - val_accuracy: 0.4717
# Epoch 39/50
# 3000/3000 [==============================] - 5s 2ms/step - loss: -3421689856.0000 - accuracy: 0.4676 - val_loss: -3499776512.0000 - val_accuracy: 0.4717
# Epoch 40/50
# 3000/3000 [==============================] - 5s 2ms/step - loss: -3682862336.0000 - accuracy: 0.4676 - val_loss: -3763582976.0000 - val_accuracy: 0.4717
# Epoch 41/50
# 3000/3000 [==============================] - 5s 2ms/step - loss: -3956538112.0000 - accuracy: 0.4676 - val_loss: -4039645952.0000 - val_accuracy: 0.4717
# Epoch 42/50
# 3000/3000 [==============================] - 5s 2ms/step - loss: -4243339008.0000 - accuracy: 0.4676 - val_loss: -4329168896.0000 - val_accuracy: 0.4717
# Epoch 43/50
# 3000/3000 [==============================] - 5s 2ms/step - loss: -4544398848.0000 - accuracy: 0.4676 - val_loss: -4632567296.0000 - val_accuracy: 0.4717
# Epoch 44/50
# 3000/3000 [==============================] - 5s 2ms/step - loss: -4858629120.0000 - accuracy: 0.4676 - val_loss: -4949026304.0000 - val_accuracy: 0.4717
# Epoch 45/50
# 3000/3000 [==============================] - 5s 2ms/step - loss: -5186886656.0000 - accuracy: 0.4676 - val_loss: -5279672832.0000 - val_accuracy: 0.4717
# Epoch 46/50
# 3000/3000 [==============================] - 5s 2ms/step - loss: -5529932800.0000 - accuracy: 0.4676 - val_loss: -5624878080.0000 - val_accuracy: 0.4717
# Epoch 47/50
# 3000/3000 [==============================] - 5s 2ms/step - loss: -5886026752.0000 - accuracy: 0.4676 - val_loss: -5983161344.0000 - val_accuracy: 0.4717
# Epoch 48/50
# 3000/3000 [==============================] - 5s 2ms/step - loss: -6258342912.0000 - accuracy: 0.4676 - val_loss: -6358566912.0000 - val_accuracy: 0.4717
# Epoch 49/50
# 3000/3000 [==============================] - 5s 2ms/step - loss: -6645726720.0000 - accuracy: 0.4676 - val_loss: -6747612672.0000 - val_accuracy: 0.4717
# Epoch 50/50
# 3000/3000 [==============================] - 5s 2ms/step - loss: -7047984128.0000 - accuracy: 0.4676 - val_loss: -7151892480.0000 - val_accuracy: 0.4717

# %%
loss, accuracy = model.evaluate(X_test, y_test)
print("Pérdida:", loss)
print("Precisión:", accuracy)
# Out:
# 750/750 [==============================] - 1s 2ms/step - loss: -7151892480.0000 - accuracy: 0.4717
# Pérdida: -7151892480.0
# Precisión: 0.4717083275318146
